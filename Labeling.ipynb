# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
data = pd.read_csv("data/PreprocessingData.csv")
data.head(5)
# Out:
#    Unnamed: 0              Tanggal&Waktu         Username  \
# 0           0  2022-06-14 08:34:52+00:00   iammasterblade
# 1           1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2           2  2022-06-14 08:34:51+00:00  mdzahid85418836
# 3           3  2022-06-14 08:34:51+00:00  annelie00284967
# 4           4  2022-06-14 08:34:51+00:00           tkirwi
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
#
#                                   Tweet_tokenization  \
# 0  ['', 'wl', 'spots', 'giveaway', 'like', 'and',...
# 1  ['', 'some', 'true', 'words', 'here', 'where',...
# 2  ['', 'runx', 'airdrop', 'million', 'rnx', 'for...
# 3  ['', 'discord', 'officially', 'opening', 'gt',...
# 4  ['', 'discord', 'officially', 'opening', 'gt',...
#
#                                         Stop_removal  \
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...
# 1               ['true', 'words', 'world', 'friend']
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...
#
#                                             Steaming
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...
# 1               ['true', 'words', 'world', 'friend']
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...

# %%
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["Clean_text"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["Clean_text"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["Clean_text"]]
data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["Clean_text"]]
data.head()
# Out:
#    Unnamed: 0              Tanggal&Waktu         Username  \
# 0           0  2022-06-14 08:34:52+00:00   iammasterblade
# 1           1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2           2  2022-06-14 08:34:51+00:00  mdzahid85418836
# 3           3  2022-06-14 08:34:51+00:00  annelie00284967
# 4           4  2022-06-14 08:34:51+00:00           tkirwi
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
#
#                                   Tweet_tokenization  \
# 0  ['', 'wl', 'spots', 'giveaway', 'like', 'and',...
# 1  ['', 'some', 'true', 'words', 'here', 'where',...
# 2  ['', 'runx', 'airdrop', 'million', 'rnx', 'for...
# 3  ['', 'discord', 'officially', 'opening', 'gt',...
# 4  ['', 'discord', 'officially', 'opening', 'gt',...
#
#                                         Stop_removal  \
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...
# 1               ['true', 'words', 'world', 'friend']
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...
#
#                                             Steaming  Positive  Negative  \
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...     0.444     0.000
# 1               ['true', 'words', 'world', 'friend']     0.375     0.000
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...     0.198     0.000
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...     0.422     0.217
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...     0.422     0.217
#
#    Neutral  Compound
# 0    0.556    0.6808
# 1    0.625    0.7184
# 2    0.802    0.5719
# 3    0.361    0.6249
# 4    0.361    0.6249

# %%
score = data["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data["Sentiment"] = sentiment
data.head()
# Out:
#    Unnamed: 0              Tanggal&Waktu         Username  \
# 0           0  2022-06-14 08:34:52+00:00   iammasterblade
# 1           1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2           2  2022-06-14 08:34:51+00:00  mdzahid85418836
# 3           3  2022-06-14 08:34:51+00:00  annelie00284967
# 4           4  2022-06-14 08:34:51+00:00           tkirwi
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
#
#                                   Tweet_tokenization  \
# 0  ['', 'wl', 'spots', 'giveaway', 'like', 'and',...
# 1  ['', 'some', 'true', 'words', 'here', 'where',...
# 2  ['', 'runx', 'airdrop', 'million', 'rnx', 'for...
# 3  ['', 'discord', 'officially', 'opening', 'gt',...
# 4  ['', 'discord', 'officially', 'opening', 'gt',...
#
#                                         Stop_removal  \
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...
# 1               ['true', 'words', 'world', 'friend']
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...
#
#                                             Steaming  Positive  Negative  \
# 0  ['wl', 'spots', 'giveaway', 'like', 'follow', ...     0.444     0.000
# 1               ['true', 'words', 'world', 'friend']     0.375     0.000
# 2  ['runx', 'airdrop', 'million', 'rnx', 'k', 'pa...     0.198     0.000
# 3  ['discord', 'officially', 'opening', 'gt', 'gt...     0.422     0.217
# 4  ['discord', 'officially', 'opening', 'gt', 'gt...     0.422     0.217
#
#    Neutral  Compound Sentiment
# 0    0.556    0.6808  Positive
# 1    0.625    0.7184  Positive
# 2    0.802    0.5719  Positive
# 3    0.361    0.6249  Positive
# 4    0.361    0.6249  Positive

# %%
print(data["Sentiment"].value_counts())
# Out:
# Positive    683
# Neutral     247
# Negative     70
# Name: Sentiment, dtype: int64

# %%
data.to_csv("data/Labeling_data.csv")
