# %% [markdown]
# # Prepocessing Data

# %%
import re
import pandas as pd
import numpy as np
import nltk
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
dataset = pd.read_csv('data/Test.csv')
dataset.head(5)
# Out:
#                Tanggal&Waktu         Username  \
# 0  2022-06-14 08:34:52+00:00   IAmMasterBlade
# 1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2  2022-06-14 08:34:51+00:00  Mdzahid85418836
# 3  2022-06-14 08:34:51+00:00  Annelie00284967
# 4  2022-06-14 08:34:51+00:00           TKirwi
#
#                                                Tweet
# 0  RT @the_sweeper_sol: 🎁 2 WL SPOTS @BakedBerser...
# 1  @Atmonez Some true words here! Where in the wo...
# 2  RT @runxofficial: 👟RunX AIRDROP: 5 MILLION RNX...
# 3  RT @NightmarePrjct: Discord Officially Opening...
# 4  RT @NightmarePrjct: Discord Officially Opening...

# %%
print(dataset.shape)
print(dataset.columns)
# print dataframe.
# Out:
# (1000, 3)
# Index(['Tanggal&Waktu', 'Username', 'Tweet'], dtype='object')

# %%
#Cleaning Text
def cleaning_text(text):
    # replace RT tag
    text = re.sub('RT\s', '', text)
    # replace @_username
    text = re.sub('\B@\w+', '', text)
    # replace URL
    text = re.sub('(http|https):\/\/\S+', '', text)
    # replace #_something_
    text = re.sub('#+', '', text)
    # konversi huruf kapital ke huruf kecil semua
    text = text.lower()
    # replace kata yang berulang-ulang ('oooooo' menjadi '00')
    text = re.sub(r'(.)\1+', r'\1\1', text)
    # replace punctuation repetition dengan single occurance ('!!!!!!' ,enjadi '!')
    text = re.sub(r'[\?\.\!]+(?=[\?.\!])', '', text)
    # menhilangkan angka dan spesial karakter, hanya mengambil alfabet saja
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    return text

dataset['Clean_text'] = dataset['Tweet'].apply(lambda x: cleaning_text(x))
dataset.head(10)
# Out:
#                Tanggal&Waktu         Username  \
# 0  2022-06-14 08:34:52+00:00   IAmMasterBlade
# 1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2  2022-06-14 08:34:51+00:00  Mdzahid85418836
# 3  2022-06-14 08:34:51+00:00  Annelie00284967
# 4  2022-06-14 08:34:51+00:00           TKirwi
# 5  2022-06-14 08:34:51+00:00    jonas18931520
# 6  2022-06-14 08:34:51+00:00  houseamacentral
# 7  2022-06-14 08:34:51+00:00     cryptoxplora
# 8  2022-06-14 08:34:50+00:00  animalsfarm_nft
# 9  2022-06-14 08:34:50+00:00       missufehan
#
#                                                Tweet  \
# 0  RT @the_sweeper_sol: 🎁 2 WL SPOTS @BakedBerser...
# 1  @Atmonez Some true words here! Where in the wo...
# 2  RT @runxofficial: 👟RunX AIRDROP: 5 MILLION RNX...
# 3  RT @NightmarePrjct: Discord Officially Opening...
# 4  RT @NightmarePrjct: Discord Officially Opening...
# 5  RT @M0range: It's not too late to join the @nf...
# 6  RT @TheBinanceNFT: Subscription for @binary_x ...
# 7  RT @marcmscs: Came such a long way…\r\nMint is...
# 8  RT @VShapr: Check out my new item on OpenSea! ...
# 9  RT @DeathFiat: 💥TOP NEWS💥#nft/ #NFTCommunity /...
#
#                                           Clean_text
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
# 5    it s not too late to join the  for the cultu...
# 6    subscription for  binaryx igo   rh nox is no...
# 7    came such a long way   mint is in less than ...
# 8            check out my new item on opensea   via
# 9     top news nft  nftcommunity   openseanft our...

# %%
#Tokenization
def tokenization_tweet(text):
    text = re.split('\W+',text)
    return text

dataset['Tweet_tokenization'] = dataset['Clean_text'].apply(lambda x: tokenization_tweet(x.lower()))
dataset.head(5)
# Out:
#                Tanggal&Waktu         Username  \
# 0  2022-06-14 08:34:52+00:00   IAmMasterBlade
# 1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2  2022-06-14 08:34:51+00:00  Mdzahid85418836
# 3  2022-06-14 08:34:51+00:00  Annelie00284967
# 4  2022-06-14 08:34:51+00:00           TKirwi
#
#                                                Tweet  \
# 0  RT @the_sweeper_sol: 🎁 2 WL SPOTS @BakedBerser...
# 1  @Atmonez Some true words here! Where in the wo...
# 2  RT @runxofficial: 👟RunX AIRDROP: 5 MILLION RNX...
# 3  RT @NightmarePrjct: Discord Officially Opening...
# 4  RT @NightmarePrjct: Discord Officially Opening...
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
#
#                                   Tweet_tokenization
# 0  [, wl, spots, giveaway, like, and, follow, and...
# 1  [, some, true, words, here, where, in, the, wo...
# 2  [, runx, airdrop, million, rnx, for, k, partic...
# 3  [, discord, officially, opening, gt, gt, passw...
# 4  [, discord, officially, opening, gt, gt, passw...

# %%
#Stop Removal

stopword = nltk.corpus.stopwords.words('english')
stopword.extend([""])

def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text

dataset['Stop_removal'] = dataset['Tweet_tokenization'].apply(lambda x: remove_stopwords(x))
dataset.head(10)
# Out:
#                Tanggal&Waktu         Username  \
# 0  2022-06-14 08:34:52+00:00   IAmMasterBlade
# 1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2  2022-06-14 08:34:51+00:00  Mdzahid85418836
# 3  2022-06-14 08:34:51+00:00  Annelie00284967
# 4  2022-06-14 08:34:51+00:00           TKirwi
# 5  2022-06-14 08:34:51+00:00    jonas18931520
# 6  2022-06-14 08:34:51+00:00  houseamacentral
# 7  2022-06-14 08:34:51+00:00     cryptoxplora
# 8  2022-06-14 08:34:50+00:00  animalsfarm_nft
# 9  2022-06-14 08:34:50+00:00       missufehan
#
#                                                Tweet  \
# 0  RT @the_sweeper_sol: 🎁 2 WL SPOTS @BakedBerser...
# 1  @Atmonez Some true words here! Where in the wo...
# 2  RT @runxofficial: 👟RunX AIRDROP: 5 MILLION RNX...
# 3  RT @NightmarePrjct: Discord Officially Opening...
# 4  RT @NightmarePrjct: Discord Officially Opening...
# 5  RT @M0range: It's not too late to join the @nf...
# 6  RT @TheBinanceNFT: Subscription for @binary_x ...
# 7  RT @marcmscs: Came such a long way…\r\nMint is...
# 8  RT @VShapr: Check out my new item on OpenSea! ...
# 9  RT @DeathFiat: 💥TOP NEWS💥#nft/ #NFTCommunity /...
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
# 5    it s not too late to join the  for the cultu...
# 6    subscription for  binaryx igo   rh nox is no...
# 7    came such a long way   mint is in less than ...
# 8            check out my new item on opensea   via
# 9     top news nft  nftcommunity   openseanft our...
#
#                                   Tweet_tokenization  \
# 0  [, wl, spots, giveaway, like, and, follow, and...
# 1  [, some, true, words, here, where, in, the, wo...
# 2  [, runx, airdrop, million, rnx, for, k, partic...
# 3  [, discord, officially, opening, gt, gt, passw...
# 4  [, discord, officially, opening, gt, gt, passw...
# 5  [, it, s, not, too, late, to, join, the, for, ...
# 6  [, subscription, for, binaryx, igo, rh, nox, i...
# 7  [, came, such, a, long, way, mint, is, in, les...
# 8  [, check, out, my, new, item, on, opensea, via, ]
# 9  [, top, news, nft, nftcommunity, openseanft, o...
#
#                                         Stop_removal
# 0  [wl, spots, giveaway, like, follow, tag, friends]
# 1                       [true, words, world, friend]
# 2  [runx, airdrop, million, rnx, k, participants,...
# 3  [discord, officially, opening, gt, gt, passwor...
# 4  [discord, officially, opening, gt, gt, passwor...
# 5  [late, join, culture, team, nonstop, work, pus...
# 6  [subscription, binaryx, igo, rh, nox, live, pr...
# 7  [came, long, way, mint, less, hours, wait, sta...
# 8                   [check, new, item, opensea, via]
# 9  [top, news, nft, nftcommunity, openseanft, top...

# %%
#Case Folding
dataset['Username'] = dataset['Username'].str.lower()
dataset.head(10)
# Out:
#                Tanggal&Waktu         Username  \
# 0  2022-06-14 08:34:52+00:00   iammasterblade
# 1  2022-06-14 08:34:51+00:00    naehrstff_nft
# 2  2022-06-14 08:34:51+00:00  mdzahid85418836
# 3  2022-06-14 08:34:51+00:00  annelie00284967
# 4  2022-06-14 08:34:51+00:00           tkirwi
# 5  2022-06-14 08:34:51+00:00    jonas18931520
# 6  2022-06-14 08:34:51+00:00  houseamacentral
# 7  2022-06-14 08:34:51+00:00     cryptoxplora
# 8  2022-06-14 08:34:50+00:00  animalsfarm_nft
# 9  2022-06-14 08:34:50+00:00       missufehan
#
#                                                Tweet  \
# 0  RT @the_sweeper_sol: 🎁 2 WL SPOTS @BakedBerser...
# 1  @Atmonez Some true words here! Where in the wo...
# 2  RT @runxofficial: 👟RunX AIRDROP: 5 MILLION RNX...
# 3  RT @NightmarePrjct: Discord Officially Opening...
# 4  RT @NightmarePrjct: Discord Officially Opening...
# 5  RT @M0range: It's not too late to join the @nf...
# 6  RT @TheBinanceNFT: Subscription for @binary_x ...
# 7  RT @marcmscs: Came such a long way…\r\nMint is...
# 8  RT @VShapr: Check out my new item on OpenSea! ...
# 9  RT @DeathFiat: 💥TOP NEWS💥#nft/ #NFTCommunity /...
#
#                                           Clean_text  \
# 0        wl spots  giveaway        like and    fo...
# 1   some true words here  where in the world are ...
# 2     runx airdrop    million rnx for   k partici...
# 3    discord officially opening        gt    gt p...
# 4    discord officially opening        gt    gt p...
# 5    it s not too late to join the  for the cultu...
# 6    subscription for  binaryx igo   rh nox is no...
# 7    came such a long way   mint is in less than ...
# 8            check out my new item on opensea   via
# 9     top news nft  nftcommunity   openseanft our...
#
#                                   Tweet_tokenization  \
# 0  [, wl, spots, giveaway, like, and, follow, and...
# 1  [, some, true, words, here, where, in, the, wo...
# 2  [, runx, airdrop, million, rnx, for, k, partic...
# 3  [, discord, officially, opening, gt, gt, passw...
# 4  [, discord, officially, opening, gt, gt, passw...
# 5  [, it, s, not, too, late, to, join, the, for, ...
# 6  [, subscription, for, binaryx, igo, rh, nox, i...
# 7  [, came, such, a, long, way, mint, is, in, les...
# 8  [, check, out, my, new, item, on, opensea, via, ]
# 9  [, top, news, nft, nftcommunity, openseanft, o...
#
#                                         Stop_removal
# 0  [wl, spots, giveaway, like, follow, tag, friends]
# 1                       [true, words, world, friend]
# 2  [runx, airdrop, million, rnx, k, participants,...
# 3  [discord, officially, opening, gt, gt, passwor...
# 4  [discord, officially, opening, gt, gt, passwor...
# 5  [late, join, culture, team, nonstop, work, pus...
# 6  [subscription, binaryx, igo, rh, nox, live, pr...
# 7  [came, long, way, mint, less, hours, wait, sta...
# 8                   [check, new, item, opensea, via]
# 9  [top, news, nft, nftcommunity, openseanft, top...

# %%
# STEMMING
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in dataset['Stop_removal']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

dataset['Steaming'] = dataset['Stop_removal'].swifter.apply(get_stemmed_term)
print(dataset['Steaming'])
# Out:
# 2044
# ------------------------
# wl : wl
# spots : spots
# giveaway : giveaway
# like : like
# follow : follow
# tag : tag
# friends : friends
# true : true
# words : words
# world : world
# friend : friend
# runx : runx
# airdrop : airdrop
# million : million
# rnx : rnx
# k : k
# participants : participants
# total : total
# reward : reward
# user : user
# per : per
# r : r
# discord : discord
# officially : officially
# opening : opening
# gt : gt
# password : password
# nmp : nmp
# win : win
# enter : enter
# rt : rt
# fol : fol
# late : late
# join : join
# culture : culture
# team : team
# nonstop : nonstop
# work : work
# pushing : pushing
# bounds : bounds
# nft : nft
# space : space
# subscription : subscription
# binaryx : binaryx
# igo : igo
# rh : rh
# nox : nox
# live : live
# prepare : prepare
# bnx : bnx
# spot : spot
# wallet : wallet
# subscribe : subscribe
# particip : particip
# came : came
# long : long
# way : way
# mint : mint
# less : less
# hours : hours
# wait : wait
# start : start
# building : building
# fam : fam
# catch : catch
# check : check
# new : new
# item : item
# opensea : opensea
# via : via
# top : top
# news : news
# nftcommunity : nftcommunity
# openseanft : openseanft
# pick : pick
# week : week
# filthy : filthy
# merica : merica
# grade : grade
# floor : floor
# price : price
# free : free
# another : another
# geeks : geeks
# made : made
# one : one
# specially : specially
# lucky : lucky
# ninjas : ninjas
# share : share
# inj : inj
# big : big
# announcement : announcement
# today : today
# want : want
# hook : hook
# undead : undead
# community : community
# giving : giving
# away : away
# x : x
# mi : mi
# time : time
# come : come
# proud : proud
# owner : owner
# unique : unique
# animated : animated
# egg : egg
# first : first
# hari : hari
# rolling : rolling
# ends : ends
# th : th
# june : june
# prize : prize
# pool : pool
# usd : usd
# worth : worth
# token : token
# winner : winner
# bitcoin : bitcoin
# crypto : crypto
# proof : proof
# stake : stake
# scam : scam
# web : web
# marketing : marketing
# buzzword : buzzword
# going : going
# zero : zero
# stablecoin : stablecoin
# love : love
# images : images
# hey : hey
# got : got
# fresh : fresh
# jacket : jacket
# sr : sr
# sloothzhangwithsloothz : sloothzhangwithsloothz
# sol : sol
# prizes : prizes
# rules : rules
# frens : frens
# hr : hr
# nftgiveaw : nftgiveaw
# alert : alert
# macd : macd
# cross : cross
# pair : pair
# eos : eos
# usdt : usdt
# ipo : ipo
# coinbase : coinbase
# cryptocurrency : cryptocurrency
# azukiart : azukiart
# also : also
# key : key
# mysterious : mysterious
# congratulations : congratulations
# early : early
# emlish : emlish
# looks : looks
# lion : lion
# nftcollection : nftcollection
# nftgiveaway : nftgiveaway
# nftgiveaways : nftgiveaways
# nftproject : nftproject
# nfts : nfts
# unknown : unknown
# places : places
# available : available
# preview : preview
# objkt : objkt
# collection : collection
# pieces : pieces
# pointcloud : pointcloud
# art : art
# open : open
# laf : laf
# winners : winners
# lets : lets
# see : see
# next : next
# wizards : wizards
# announcing : announcing
# gold : gold
# genesis : genesis
# wizard : wizard
# pass : pass
# cost : cost
# gas : gas
# uti : uti
# oak : oak
# paradise : paradise
# wls : wls
# fr : fr
# updates : updates
# hiding : hiding
# suspicious : suspicious
# transfers : transfers
# kujira : kujira
# network : network
# public : public
# testnet : testnet
# harpoon : harpoon
# l : l
# raising : raising
# fund : fund
# research : research
# legalization : legalization
# efforts : efforts
# psychedelic : psychedelic
# treatments : treatments
# depression : depression
# ptsd : ptsd
# b : b
# take : take
# part : part
# exclusive : exclusive
# challenge : challenge
# amp : amp
# attractive : attractive
# burn : burn
# mobox : mobox
# momoverse : momoverse
# avatars : avatars
# make : make
# sure : sure
# need : need
# help : help
# hi : hi
# tronics : tronics
# operation : operation
# commissioning : commissioning
# meme : meme
# fan : fan
# contest : contest
# st : st
# tagosoul : tagosoul
# begun : begun
# tago : tago
# slots : slots
# whitelist : whitelist
# eth : eth
# cheer : cheer
# person : person
# luminal : luminal
# newnftprofilepic : newnftprofilepic
# soulmate : soulmate
# gave : gave
# coveted : coveted
# wish : wish
# bet : bet
# bigfoot : bigfoot
# town : town
# apple : apple
# lie : lie
# right : right
# something : something
# different : different
# look : look
# move : move
# earn : earn
# metaverse : metaverse
# ido : ido
# think : think
# project : project
# successful : successful
# transparency : transparency
# safety : safety
# funkopop : funkopop
# toy : toy
# pop : pop
# webstore : webstore
# ht : ht
# hellyeeah : hellyeeah
# dust : dust
# minting : minting
# rn : rn
# day : day
# since : since
# launching : launching
# full : full
# website : website
# summon : summon
# list : list
# spo : spo
# drop : drop
# address : address
# registered : registered
# lilchimps : lilchimps
# secret : secret
# alpha : alpha
# labs : labs
# nubbies : nubbies
# profits : profits
# trading : trading
# cars : cars
# upgraded : upgraded
# caryptoapp : caryptoapp
# blockchains : blockchains
# coincollectors : coincollectors
# attending : attending
# barcelona : barcelona
# forget : forget
# collect : collect
# created : created
# already : already
# date : date
# arrival : arrival
# addition : addition
# know : know
# chance : chance
# get : get
# cl : cl
# submitted : submitted
# offer : offer
# hope : hope
# build : build
# hub : hub
# exciting : exciting
# times : times
# ahead : ahead
# steps : steps
# login : login
# cmc : cmc
# mones : mones
# thanks : thanks
# retweet : retweet
# pinned : pinned
# welcome : welcome
# gang : gang
# known : known
# require : require
# host : host
# technologies : technologies
# combinatorial : combinatorial
# innovations : innovations
# product : product
# leaders : leaders
# across : across
# industries : industries
# must : must
# invest : invest
# thank : thank
# dear : dear
# supporting : supporting
# really : really
# buying : buying
# fuck : fuck
# bear : bear
# market : market
# diao : diao
# club : club
# rate : rate
# qualified : qualified
# entra : entra
# digitalart : digitalart
# intothevoid : intothevoid
# nftart : nftart
# nftcollector : nftcollector
# nftmint : nftmint
# inthenextweek : inthenextweek
# sl : sl
# heard : heard
# dropping : dropping
# huge : huge
# og : og
# roles : roles
# ldd : ldd
# recruits : recruits
# enlist : enlist
# become : become
# bheroes : bheroes
# born : born
# bh : bh
# agents : agents
# stand : stand
# ou : ou
# creators : creators
# ape : ape
# etc : etc
# holders : holders
# addresses : addresses
# vip : vip
# role : role
# claim : claim
# hour : hour
# count : count
# living : living
# football : football
# helmets : helmets
# soon : soon
# giveway : giveway
# airdrops : airdrops
# digital : digital
# season : season
# eve : eve
# meta : meta
# human : human
# fashion : fashion
# model : model
# metawear : metawear
# alive : alive
# saw : saw
# modeling : modeling
# fashi : fashi
# phase : phase
# ii : ii
# courtesy : courtesy
# amazing : amazing
# partners : partners
# reckless : reckless
# racoon : racoon
# gangsta : gangsta
# goonz : goonz
# united : united
# states : states
# ranked : ranked
# companies : companies
# country : country
# many : many
# companie : companie
# lot : lot
# yoo : yoo
# gg : gg
# gonna : gonna
# smash : smash
# buy : buy
# followers : followers
# bellow : bellow
# elfs : elfs
# unified : unified
# defeat : defeat
# goblins : goblins
# elftownwtf : elftownwtf
# elftown : elftown
# tokenz : tokenz
# cap : cap
# changes : changes
# mona : mona
# arcona : arcona
# moov : moov
# locg : locg
# congrats : congrats
# flash : flash
# mfb : mfb
# millenabots : millenabots
# king : king
# hell : hell
# submission : submission
# penhead : penhead
# cool : cool
# approach : approach
# fun : fun
# stones : stones
# projects : projects
# trouble : trouble
# problem : problem
# volume : volume
# revenue : revenue
# collected : collected
# pa : pa
# members : members
# presenting : presenting
# genisis : genis
# sentience : sentience
# capacity : capacity
# wonderful : wonderful
# happy : happy
# children : children
# still : still
# remember : remember
# best : best
# childhood : childhood
# memory : memory
# mind : mind
# blessing : blessing
# co : co
# gm : gm
# interesting : interesting
# goals : goals
# pr : pr
# running : running
# much : much
# bilibili : bilibili
# comics : comics
# search : search
# great : great
# level : level
# favorite : favorite
# fanartfriday : fanartfriday
# ready : ready
# use : use
# heroes : heroes
# several : several
# games : games
# boost : boost
# gaming : gaming
# experience : experience
# max : max
# er : er
# feature : feature
# game : game
# play : play
# mechanism : mechanism
# provides : provides
# pla : pla
# highlights : highlights
# varying : varying
# rarity : rarity
# accessories : accessories
# owners : owners
# freemint : freemint
# postponed : postponed
# due : due
# celsius : celsius
# isues : isues
# private : private
# changed : changed
# announce : announce
# ab : ab
# oat : oat
# campaign : campaign
# learn : learn
# please : please
# lin : lin
# yet : yet
# ducks : ducks
# row : row
# quackity : quackity
# baby : baby
# muse : muse
# call : call
# fatman : fatman
# rasmus : rasmus
# dogs : dogs
# anericanbullies : anericanbullies
# california : california
# nigeria : nigeria
# auc : auc
# sold : sold
# favourite : favourite
# accounts : accounts
# nftsold : nftsold
# landscape : landscape
# involving : involving
# library : library
# zfh : zfh
# artist : artist
# artwork : artwork
# tonight : tonight
# future : future
# blockchain : blockchain
# apaches : apaches
# dissemination : dissemination
# native : native
# american : american
# tribes : tribes
# inspire : inspire
# showdown : showdown
# consensus : consensus
# reignofterror : reignofterror
# heading : heading
# leading : leading
# largest : largest
# event : event
# ucc : ucc
# hacked : hacked
# sign : sign
# anything : anything
# group : group
# careful : careful
# message : message
# avax : avax
# giveaways : giveaways
# last : last
# report : report
# value : value
# patient : patient
# hard : hard
# refferal : refferal
# slot : slot
# final : final
# launchpad : launchpad
# mirror : mirror
# gen : gen
# sale : sale
# pm : pm
# utc : utc
# est : est
# pubic : pubic
# separate : separate
# needed : needed
# fee : fee
# ser : ser
# lovely : lovely
# souls : souls
# care : care
# profession : profession
# matter : matter
# small : small
# foundation : foundation
# life : life
# yo : yo
# sell : sell
# orders : orders
# supply : supply
# keep : keep
# bon : bon
# ai : ai
# biggest : biggest
# risk : risk
# taking : taking
# e : e
# fananees : fananees
# v : v
# finally : finally
# excited : excited
# journey : journey
# fana : fana
# someone : someone
# thinks : thinks
# needs : needs
# fren : fren
# people : people
# hav : hav
# appreciate : appreciate
# haha : haha
# agent : agent
# wearesinners : wearesinners
# zooverse : zooverse
# shh : shh
# given : given
# us : us
# done : done
# hello : hello
# gate : gate
# users : users
# dkr : dkr
# commemorate : commemorate
# listing : listing
# good : good
# collecting : collecting
# investment : investment
# developing : developing
# moving : moving
# confiden : confiden
# buddy : buddy
# devious : devious
# romeo : romeo
# absolutely : absolutely
# perfect : perfect
# comic : comic
# rent : rent
# head : head
# animeedit : animeedit
# turn : turn
# h : h
# lfg : lfg
# extremely : extremely
# reveal : reveal
# shibaverse : shibaverse
# shiballoon : shiballoon
# besties : besties
# food : food
# truck : truck
# menu : menu
# night : night
# nyc : nyc
# family : family
# friendly : friendly
# indigo : indigo
# stoyan : stoyan
# informative : informative
# wealth : wealth
# knowledge : knowledge
# shit : shit
# condition : condition
# give : give
# rare : rare
# goblin : goblin
# fucked : fucked
# every : every
# interaction : interaction
# considered : considered
# w : w
# raffles : raffles
# allocated : allocated
# con : con
# presents : presents
# celt : celt
# mystery : mystery
# box : box
# jun : jun
# entry : entry
# oseanworld : oseanworld
# realm : realm
# debut : debut
# nu : nu
# radio : radio
# highsnobiety : highsnobiety
# questions : questions
# fantastic : fantastic
# ama : ama
# talking : talking
# upcoming : upcoming
# totem : totem
# fpx : fpx
# lolm : lolm
# set : set
# singapore : singapore
# success : success
# participate : participate
# foll : foll
# warden : warden
# marketplace : marketplace
# metawardennft : metawardennft
# mwad : mwad
# belle : belle
# octomorphosis : octomorphosis
# bold : bold
# empowered : empowered
# courageous : courageous
# cutelittlefoxes : cutelittlefoxes
# poligon : poligon
# kirara : kirara
# link : link
# commen : commen
# gamers : gamers
# looking : looking
# forward : forward
# thing : thing
# winn : winn
# dreaming : dreaming
# controlling : controlling
# shares : shares
# fo : fo
# weird : weird
# dudes : dudes
# miss : miss
# anon : anon
# staking : staking
# aft : aft
# greeting : greeting
# gwer : gwer
# fairyland : fairyland
# beta : beta
# launched : launched
# adventure : adventure
# di : di
# doodle : doodle
# walle : walle
# official : official
# tool : tool
# nobody : nobody
# safe : safe
# lambocorp : lambocorp
# mega : mega
# celebrate : celebrate
# launch : launch
# trove : trove
# mechapunkx : mechapunkx
# awakened : awakened
# morning : morning
# letter : letter
# stratosphere : stratosphere
# exhibition : exhibition
# became : became
# p : p
# polygon : polygon
# uss : uss
# adopt : adopt
# otherside : otherside
# pin : pin
# tweet : tweet
# required : required
# nftgivea : nftgivea
# offering : offering
# grove : grove
# joining : joining
# promisphere : promisphere
# sgt : sgt
# mafia : mafia
# themed : themed
# bloc : bloc
# powerful : powerful
# listed : listed
# power : power
# nature : nature
# reserve : reserve
# items : items
# support : support
# nftjapan : nftjapan
# htt : htt
# lc : lc
# choose : choose
# avatar : avatar
# fantasticcarl : fantasticcarl
# randomly : randomly
# generated : generated
# carls : carls
# ethereum : ethereum
# carl : carl
# acce : acce
# tomorrow : tomorrow
# together : together
# hmm : hmm
# gameplay : gameplay
# chill : chill
# af : af
# manage : manage
# finances : finances
# place : place
# pay : pay
# year : year
# personal : personal
# finance : finance
# app : app
# hit : hit
# crazyfrog : crazyfrog
# xgem : xgem
# craziest : craziest
# pump : pump
# stable : stable
# loyal : loyal
# growing : growing
# war : war
# reacted : reacted
# save : save
# proofs : proofs
# inf : inf
# sending : sending
# hugs : hugs
# fellow : fellow
# artists : artists
# collectors : collectors
# rough : rough
# stop : stop
# shilling : shilling
# pls : pls
# strawberry : strawberry
# moon : moon
# hunt : hunt
# comment : comment
# find : find
# luck : luck
# everybody : everybody
# kryptomon : kryptomon
# girl : girl
# bought : bought
# point : point
# yorkers : yorkers
# gotta : gotta
# damn : damn
# mugged : mugged
# coming : coming
# city : city
# omni : omni
# collab : collab
# partnered : partnered
# f : f
# landz : landz
# metararity : metararity
# calder : calder
# moore : moore
# sculpture : sculpture
# minimalkitten : minimalkitten
# basic : basic
# nftprojec : nftprojec
# presale : presale
# chapter : chapter
# whitelists : whitelists
# enjoy : enjoy
# socia : socia
# show : show
# gives : gives
# slowly : slowly
# valuable : valuable
# strong : strong
# read : read
# horse : horse
# peeps : peeps
# guy : guy
# video : video
# begins : begins
# gmt : gmt
# mints : mints
# others : others
# n : n
# boxes : boxes
# test : test
# ever : ever
# bug : bug
# send : send
# email : email
# gamewonderlab : gamewonderlab
# io : io
# yeah : yeah
# literally : literally
# participated : participated
# weekly : weekly
# sharin : sharin
# unsold : unsold
# bees : bees
# nftcolle : nftcolle
# sac : sac
# holder : holder
# order : order
# gravity : gravity
# bong : bong
# discount : discount
# digitalimmortality : digitalimmortality
# two : two
# heritage : heritage
# passes : passes
# complete : complete
# tasks : tasks
# least : least
# dbits : dbits
# uno : uno
# random : random
# zapes : zapes
# zombieapes : zombieapes
# getting : getting
# started : started
# wen : wen
# verified : verified
# solana : solana
# warm : warm
# skins : skins
# tap : tap
# fantasy : fantasy
# let : let
# go : go
# ride : ride
# grab : grab
# ticket : ticket
# train : train
# leaving : leaving
# downtow : downtow
# acc : acc
# details : details
# guys : guys
# breaking : breaking
# metadragnarok : metadragnarok
# metadragnarokers : metadragnarokers
# focus : focus
# launc : launc
# raffle : raffle
# channel : channel
# guaranteed : guaranteed
# post : post
# almost : almost
# olyverse : olyverse
# twitter : twitter
# instagr : instagr
# nftcommuni : nftcommuni
# motivated : motivated
# teach : teach
# happen : happen
# heat : heat
# theskeletonsarecoming : theskeletonsarecoming
# black : black
# tailed : tailed
# godwit : godwit
# endangered : endangered
# species : species
# territorial : territorial
# figh : figh
# ent : ent
# recall : recall
# rather : rather
# hair : hair
# portrait : portrait
# applepencil : applepencil
# artistontwitter : artistontwitter
# artshare : artshare
# illustration : illustration
# cosmotourist : cosmotourist
# mission : mission
# engineer : engineer
# rocket : rocket
# interstellar : interstellar
# flights : flights
# colonization : colonization
# planets : planets
# explosion : explosion
# selling : selling
# encryption : encryption
# enlarged : enlarged
# lost : lost
# motivate : motivate
# happiness : happiness
# everyday : everyday
# primavera : primavera
# sound : sound
# att : att
# successor : successor
# treasure : treasure
# marketpla : marketpla
# totally : totally
# close : close
# alway : alway
# icx : icx
# hodl : hodl
# credits : credits
# expedition : expedition
# avalanche : avalanche
# acquire : acquire
# famous : famous
# zoobooster : zoobooster
# staki : staki
# https : https
# everyone : everyone
# wins : wins
# pic : pic
# party : party
# cst : cst
# truely : truely
# historic : historic
# document : document
# anywhere : anywhere
# ugly : ugly
# pets : pets
# little : little
# bout : bout
# chicken : chicken
# coop : coop
# ico : ico
# end : end
# days : days
# gulf : gulf
# exchange : exchange
# faceless : faceless
# ta : ta
# ruin : ruin
# thread : thread
# solananfts : solananfts
# lava : lava
# screen : screen
# non : non
# shitbeast : shitbeast
# wanting : wanting
# nostalgia : nostalgia
# nd : nd
# scre : scre
# gmgm : gmgm
# annebel : annebel
# well : well
# cnftgiveaway : cnftgiveaway
# senate : senate
# nodes : nodes
# galactic : galactic
# weeks : weeks
# dia : dia
# okayy : okayy
# rest : rest
# woof : woof
# among : among
# sharks : sharks
# service : service
# provider : provider
# sciencemagic : sciencemagic
# studios : studios
# raised : raised
# pre : pre
# seed : seed
# round : round
# testing : testing
# activationcode : activationcode
# category : category
# finger : finger
# hustler : hustler
# urban : urban
# dragons : dragons
# roadmap : roadmap
# pleasure : pleasure
# phases : phases
# proyect : proyect
# beautiful : beautiful
# piece : piece
# finalizing : finalizing
# even : even
# informed : informed
# economics : economics
# observer : observer
# aware : aware
# scale : scale
# bubble : bubble
# said : said
# consumption : consumption
# withou : withou
# dubai : dubai
# expo : expo
# metaversegame : metaversegame
# legends : legends
# discuss : discuss
# fight : fight
# founder : founder
# attention : attention
# minimum : minimum
# binance : binance
# busd : busd
# encouraged : encouraged
# increase : increase
# bonus : bonus
# mainnet : mainnet
# ens : ens
# fear : fear
# greed : greed
# index : index
# extreme : extreme
# current : current
# sum : sum
# evo : evo
# surfers : surfers
# testers : testers
# jt : jt
# miracles : miracles
# believe : believe
# color : color
# equivalent : equivalent
# wear : wear
# super : super
# mvp : mvp
# glad : glad
# auction : auction
# mai : mai
# san : san
# desu : desu
# change : change
# moment : moment
# wishes : wishes
# interactions : interactions
# unnoticed : unnoticed
# rich : rich
# eva : eva
# magiccrafters : magiccrafters
# missing : missing
# mcnft : mcnft
# mages : mages
# archers : archers
# warriors : warriors
# curious : curious
# road : road
# gonzaga : gonzaga
# mean : mean
# feel : feel
# beauty : beauty
# giveaw : giveaw
# xwolf : xwolf
# tidbit : tidbit
# designs : designs
# u : u
# managed : managed
# bnftxprimavera : bnftxprimavera
# bi : bi
# airdropping : airdropping
# hold : hold
# within : within
# instead : instead
# using : using
# crayons : crayons
# glitters : glitters
# ribbons : ribbons
# bring : bring
# uniqueness : uniqueness
# comes : comes
# ne : ne
# amped : amped
# wild : wild
# phantom : phantom
# edition : edition
# bless : bless
# thy : thy
# daily : daily
# form : form
# abga : abga
# partner : partner
# sponsored : sponsored
# institutions : institutions
# buildi : buildi
# organizing : organizing
# speed : speed
# dating : dating
# would : would
# watch : watch
# tv : tv
# psychomolly : psychomolly
# special : special
# limited : limited
# psyc : psyc
# oliver : oliver
# heldens : heldens
# releases : releases
# oli : oli
# gecko : gecko
# newnft : newnft
# walken : walken
# multiplayer : multiplayer
# tournament : tournament
# rewards : rewards
# defeating : defeating
# oppone : oppone
# brands : brands
# avoid : avoid
# sustainability : sustainability
# paradox : paradox
# bapes : bapes
# fri : fri
# delicate : delicate
# appetizer : appetizer
# blockpi : blockpi
# incentivized : incentivized
# cam : cam
# cour : cour
# log : log
# citizens : citizens
# planet : planet
# g : g
# invite : invite
# intergalactic : intergalactic
# qualify : qualify
# lik : lik
# fixation : fixation
# death : death
# fluidity : fluidity
# miyamoto : miyamoto
# musashi : musashi
# title : title
# towards : towards
# rbxs : rbxs
# destination : destination
# milli : milli
# mino : mino
# cats : cats
# painting : painting
# pac : pac
# painted : painted
# thursday : thursday
# shipped : shipped
# catlook : catlook
# released : released
# peakywolves : peakywolves
# bro : bro
# btw : btw
# eat : eat
# mostly : mostly
# lunch : lunch
# drawing : drawing
# goldlesy : goldlesy
# white : white
# yea : yea
# wishing : wishing
# gerat : gerat
# friday : friday
# prime : prime
# idr : idr
# celebration : celebration
# et : et
# click : click
# closing : closing
# highest : highest
# hopefully : hopefully
# plan : plan
# converted : converted
# treasuries : treasuries
# fiat : fiat
# touched : touched
# gyrfalcon : gyrfalcon
# nftf : nftf
# falcon : falcon
# racing : racing
# starting : starting
# bid : bid
# collaboration : collaboration
# legend : legend
# rapper : rapper
# anarchy : anarchy
# nexfi : nexfi
# information : information
# regar : regar
# eligible : eligible
# phone : phone
# old : old
# btc : btc
# taker : taker
# dive : dive
# whitelisted : whitelisted
# smart : smart
# contracts : contracts
# hottest : hottest
# trending : trending
# collections : collections
# deposit : deposit
# trade : trade
# wanna : wanna
# cult : cult
# enters : enters
# c : c
# flower : flower
# nice : nice
# dante : dante
# oil : oil
# ukraine : ukraine
# bankaccount : bankaccount
# min : min
# weth : weth
# gtm : gtm
# promo : promo
# bank : bank
# pi : pi
# ata : ata
# containing : containing
# luchador : luchador
# wearable : wearable
# j : j
# meet : meet
# hakako : hakako
# version : version
# crowdsales : crowdsales
# sales : sales
# gn : gn
# willow : willow
# oh : oh
# idea : idea
# nfta : nfta
# young : young
# fela : fela
# reincarnation : reincarnation
# photography : photography
# music : music
# elements : elements
# kingdom : kingdom
# tattva : tattva
# carbon : carbon
# introducing : introducing
# pledge : pledge
# platform : platform
# stress : stress
# busy : busy
# high : high
# conviction : conviction
# buyers : buyers
# pri : pri
# shark : shark
# bubblefong : bubblefong
# grabs : grabs
# hobos : hobos
# everywhere : everywhere
# sadboys : sadboys
# reach : reach
# century : century
# social : social
# alpacadabraz : alpacadabraz
# brand : brand
# ecosystem : ecosystem
# intersection : intersection
# defi : defi
# networks : networks
# corporate : corporate
# sponsor : sponsor
# region : region
# lea : lea
# celebrating : celebrating
# captain : captain
# water : water
# rings : rings
# winne : winne
# qtum : qtum
# dreams : dreams
# begin : begin
# definitely : definitely
# inspiration : inspiration
# innovative : innovative
# approaches : approaches
# gangnam : gangnam
# korea : korea
# inspired : inspired
# dracoo : dracoo
# champion : champion
# series : series
# master : master
# esports : esports
# highlighted : highlighted
# pioneers : pioneers
# thousands : thousands
# fi : fi
# gobween : gobween
# sneak : sneak
# peek : peek
# dark : dark
# element : element
# yoleeuniverse : yoleeuniverse
# finished : finished
# participation : participation
# gamefi : gamefi
# nftdrop : nftdrop
# notified : notified
# dm : dm
# birthday : birthday
# liquidifty : liquidifty
# hooray : hooray
# prepared : prepared
# gifts : gifts
# sta : sta
# cute : cute
# ice : ice
# creams : creams
# pear : pear
# lemon : lemon
# mousse : mousse
# imagine : imagine
# combination : combination
# sweet : sweet
# sour : sour
# mouss : mouss
# interestingly : interestingly
# acting : acting
# bullish : bullish
# hands : hands
# lately : lately
# numbers : numbers
# plummeting : plummeting
# panic : panic
# gener : gener
# nftartist : nftartist
# nftcollectors : nftcollectors
# arttoad : arttoad
# nf : nf
# magical : magical
# mutts : mutts
# powered : powered
# ar : ar
# physical : physical
# canvas : canvas
# itg : itg
# bird : bird
# eastern : eastern
# bluebird : bluebird
# original : original
# oilpainting : oilpainting
# har : har
# blender : blender
# drender : drender
# gets : gets
# never : never
# snipe : snipe
# toolbox : toolbox
# track : track
# mass : mass
# bulk : bulk
# bnb : bnb
# chain : chain
# aiming : aiming
# unpredictable : unpredictable
# citizen : citizen
# pfp : pfp
# characterdesign : characterdesign
# artnft : artnft
# grandpa : grandpa
# rank : rank
# trait : trait
# doctor : doctor
# coat : coat
# oxaluswallet : oxaluswallet
# gunx : gunx
# draw : draw
# smulips : smulips
# safest : safest
# marvel : marvel
# licensed : licensed
# dollar : dollar
# counterpart : counterpart
# code : code
# samco : samco
# gallery : gallery
# oncyber : oncyber
# bugcity : bugcity
# matic : matic
# traders : traders
# short : short
# bearish : bearish
# marubozu : marubozu
# doji : doji
# prototype : prototype
# logo : logo
# xoxno : xoxno
# golden : golden
# plus : plus
# mpp : mpp
# tokens : tokens
# thrilled : thrilled
# bluca : bluca
# greek : greek
# mythical : mythical
# dropped : dropped
# traits : traits
# cryptoartist : cryptoartist
# ada : ada
# technology : technology
# supplychain : supplychain
# buddylist : buddylist
# fanart : fanart
# operationsin : operationsin
# dart : dart
# nftdrops : nftdrops
# redditplace : redditplace
# pixelart : pixelart
# graffiti : graffiti
# wall : wall
# players : players
# angel : angel
# hidden : hidden
# magicforest : magicforest
# expect : expect
# kill : kill
# monsters : monsters
# seco : seco
# inspir : inspir
# sleeve : sleeve
# eight : eight
# posted : posted
# prices : prices
# minutes : minutes
# creation : creation
# content : content
# gamification : gamification
# starts : starts
# customization : customization
# solananft : solananft
# slow : slow
# verifications : verifications
# everything : everything
# though : though
# difficult : difficult
# surely : surely
# omfg : omfg
# realized : realized
# pushed : pushed
# fine : fine
# hou : hou
# buddies : buddies
# donating : donating
# awesome : awesome
# forest : forest
# ap : ap
# teamed : teamed
# cro : cro
# collec : collec
# joined : joined
# abo : abo
# pig : pig
# speechless : speechless
# grow : grow
# enthusiasts : enthusiasts
# builders : builders
# memorable : memorable
# remar : remar
# buyer : buyer
# im : im
# back : back
# card : card
# packs : packs
# rule : rule
# dc : dc
# tradertersesat : tradertersesat
# called : called
# bridge : bridge
# remaining : remaining
# mancunian : mancunian
# moments : moments
# amazi : amazi
# benefit : benefit
# casino : casino
# lootboxes : lootboxes
# featur : featur
# engine : engine
# used : used
# ga : ga
# currently : currently
# happening : happening
# peop : peop
# forms : forms
# serving : serving
# purposes : purposes
# shill : shill
# dope : dope
# noirslasher : noirslasher
# found : found
# nigh : nigh
# jedi : jedi
# minted : minted
# litter : litter
# picked : picked
# hrs : hrs
# ad : ad
# relevant : relevant
# say : say
# walk : walk
# improve : improve
# cathlete : cathlete
# describe : describe
# popular : popular
# concept : concept
# fie : fie
# nftairdrops : nftairdrops
# solangel : solangel
# position : position
# often : often
# always : always
# bloated : bloated
# unbalanced : unbalanced
# dem : dem
# goodmorning : goodmorning
# glory : glory
# blockchaingaming : blockchaingaming
# gamedev : gamedev
# honor : honor
# strategic : strategic
# partnership : partnership
# aggregator : aggregator
# backed : backed
# inspi : inspi
# fomoin : fomoin
# sharing : sharing
# taboopunks : taboopunks
# introduced : introduced
# large : large
# highly : highly
# reputable : reputable
# speaking : speaking
# rosenaz : rosenaz
# nftar : nftar
# emerging : emerging
# roll : roll
# flipping : flipping
# nfs : nfs
# vibe : vibe
# babylon : babylon
# create : create
# hologram : hologram
# style : style
# demonix : demonix
# cubeanz : cubeanz
# en : en
# boom : boom
# nftshill : nftshill
# centric : centric
# investments : investments
# underway : underway
# register : register
# reduce : reduce
# bots : bots
# chainplay : chainplay
# skull : skull
# catz : catz
# held : held
# ago : ago
# dro : dro
# anyone : anyone
# wants : wants
# airborne : airborne
# paratrooperz : paratrooperz
# july : july
# homies : homies
# oriental : oriental
# derived : derived
# cryptos : cryptos
# derivative : derivative
# forex : forex
# stage : stage
# ex : ex
# gem : gem
# sweep : sweep
# ill : ill
# poop : poop
# marvininu : marvininu
# stacking : stacking
# commonly : commonly
# field : field
# currencies : currencies
# sticking : sticking
# means : means
# making : making
# profit : profit
# exc : exc
# seeing : seeing
# soo : soo
# related : related
# tweets : tweets
# typed : typed
# otherdeed : otherdeed
# poopy : poopy
# rock : rock
# pet : pet
# update : update
# reclaiming : reclaiming
# stolen : stolen
# african : african
# artifacts : artifacts
# paying : paying
# tribute : tribute
# num : num
# common : common
# goods : goods
# parts : parts
# pringo : pringo
# incentives : incentives
# ol : ol
# mm : mm
# metad : metad
# seconds : seconds
# character : character
# story : story
# number : number
# half : half
# joe : joe
# mecha : mecha
# poor : poor
# bastard : bastard
# taken : taken
# bit : bit
# beating : beating
# armour : armour
# actual : actual
# comicbooks : comicbooks
# anti : anti
# mimesis : mimesis
# plot : plot
# tw : tw
# kitsunebi : kitsunebi
# lemontea : lemontea
# drew : drew
# characters : characters
# present : present
# jellyfish : jellyfish
# psychedelicskulls : psychedelicskulls
# skulls : skulls
# magic : magic
# castle : castle
# zookee : zookee
# told : told
# dzw : dzw
# guardian : guardian
# formed : formed
# dancing : dancing
# ban : ban
# rec : rec
# degensol : degensol
# magiceden : magiceden
# honey : honey
# alphasharks : alphasharks
# extension : extension
# everrise : everrise
# quiz : quiz
# tuesday : tuesday
# question : question
# rise : rise
# professional : professional
# break : break
# pro : pro
# knowled : knowled
# marvin : marvin
# things : things
# fill : fill
# bag : bag
# sheet : sheet
# finals : finals
# cse : cse
# tribulation : tribulation
# wisdom : wisdom
# summing : summing
# greatness : greatness
# god : god
# grace : grace
# parting : parting
# sea : sea
# perfectl : perfectl
# lapse : lapse
# staycation : staycation
# rainy : rainy
# da : da
# se : se
# exploring : exploring
# options : options
# venture : venture
# capital : capital
# firm : firm
# speak : speak
# decided : decided
# wit : wit
# cc : cc
# crash : crash
# elli : elli
# ye : ye
# spell : spell
# book : book
# resold : resold
# bidding : bidding
# node : node
# access : access
# spend : spend
# raining : raining
# outside : outside
# utility : utility
# past : past
# stages : stages
# beyond : beyond
# stars : stars
# nftnusantara : nftnusantara
# patron : patron
# performing : performing
# assets : assets
# seraphim : seraphim
# sensei : sensei
# sir : sir
# anime : anime
# took : took
# rendering : rendering
# ed : ed
# cfe : cfe
# cbc : cbc
# senzoku : senzoku
# chosen : chosen
# develop : develop
# makin : makin
# turds : turds
# without : without
# yes : yes
# cardano : cardano
# innovation : innovation
# neverland : neverland
# mentioned : mentioned
# coin : coin
# mars : mars
# claiming : claiming
# wax : wax
# zesty : zesty
# faucet : faucet
# unlock : unlock
# dfc : dfc
# cake : cake
# xtz : xtz
# rari : rari
# kyub : kyub
# kiba : kiba
# bscs : bscs
# diva : diva
# resist : resist
# roar : roar
# lionfollowlion : lionfollowlion
# blocklike : blocklike
# panel : panel
# topic : topic
# built : built
# sketch : sketch
# zbrush : zbrush
# keyshot : keyshot
# introduce : introduce
# doll : doll
# swag : swag
# dolls : dolls
# name : name
# rainbo : rainbo
# omg : omg
# girlmong : girlmong
# goodnight : goodnight
# typo : typo
# tank : tank
# sho : sho
# crashing : crashing
# alongside : alongside
# architectural : architectural
# around : around
# certified : certified
# http : http
# samurai : samurai
# ronins : ronins
# dobies : dobies
# rsvp : rsvp
# wil : wil
# cronos : cronos
# fftb : fftb
# crofam : crofam
# cronosnf : cronosnf
# tokenlands : tokenlands
# tagging : tagging
# loved : loved
# honored : honored
# latest : latest
# integration : integration
# according : according
# allows : allows
# developers : developers
# deploy : deploy
# applicatio : applicatio
# freenft : freenft
# nftcollections : nftcollections
# discovering : discovering
# meaning : meaning
# property : property
# internet : internet
# later : later
# activities : activities
# fluffles : fluffles
# hyp : hyp
# panicking : panicking
# aims : aims
# term : term
# wi : wi
# contains : contains
# handmade : handmade
# feels : feels
# miles : miles
# transmission : transmission
# received : received
# decoding : decoding
# candidates : candidates
# interact : interact
# rewarded : rewarded
# fangster : fangster
# bitvots : bitvots
# fair : fair
# estimate : estimate
# revealing : revealing
# cosmos : cosmos
# sdk : sdk
# simple : simple
# alright : alright
# megumin : megumin
# variant : variant
# chomusuke : chomusuke
# catalina : catalina
# poster : poster
# combo : combo
# alinaverse : alinaverse
# lacedameon : lacedameon
# mil : mil
# mandox : mandox
# multiple : multiple
# player : player
# bombpop : bombpop
# hoodie : hoodie
# following : following
# takes : takes
# wow : wow
# crv : crv
# ksm : ksm
# okb : okb
# chz : chz
# celo : celo
# thiss : thiss
# sup : sup
# tych : tych
# seller : seller
# elves : elves
# ccg : ccg
# spellfire : spellfire
# bad : bad
# vehicle : vehicle
# tesla : tesla
# cybertruck : cybertruck
# opportunity : opportunity
# embassy : embassy
# package : package
# release : release
# important : important
# rug : rug
# pulls : pulls
# helpful : helpful
# tips : tips
# articl : articl
# vial : vial
# sto : sto
# low : low
# wagmi : wagmi
# cactusworldnft : cactusworldnft
# cactusworldtv : cactusworldtv
# leftoverz : leftoverz
# could : could
# lt : lt
# vivatech : vivatech
# attendees : attendees
# onsite : onsite
# cola : cola
# mary : mary
# jane : jane
# bottle : bottle
# digi : digi
# caps : caps
# collector : collector
# waiting : waiting
# application : application
# response : response
# ko : ko
# compromised : compromised
# onto : onto
# quite : quite
# shitty : shitty
# else : else
# real : real
# charts : charts
# women : women
# galaxy : galaxy
# char : char
# booblist : booblist
# meanwhile : meanwhile
# asupremacy : asupremacy
# blocksmith : blocksmith
# purchased : purchased
# discover : discover
# changing : changing
# online : online
# yuser : yuser
# polkadot : polkadot
# stay : stay
# control : control
# virus : virus
# lives : lives
# brilliant : brilliant
# fluffy : fluffy
# animeart : animeart
# animenft : animenft
# karachi : karachi
# metagorgeous : metagorgeous
# waters : waters
# metagorgeo : metagorgeo
# satari : satar
# studio : studio
# wrote : wrote
# medium : medium
# article : article
# explaining : explaining
# instructions : instructions
# dusktopia : dusktopia
# hydrated : hydrated
# delightful : delightful
# summer : summer
# pill : pill
# summervibes : summervibes
# summertime : summertime
# {'wl': 'wl', 'spots': 'spots', 'giveaway': 'giveaway', 'like': 'like', 'follow': 'follow', 'tag': 'tag', 'friends': 'friends', 'true': 'true', 'words': 'words', 'world': 'world', 'friend': 'friend', 'runx': 'runx', 'airdrop': 'airdrop', 'million': 'million', 'rnx': 'rnx', 'k': 'k', 'participants': 'participants', 'total': 'total', 'reward': 'reward', 'user': 'user', 'per': 'per', 'r': 'r', 'discord': 'discord', 'officially': 'officially', 'opening': 'opening', 'gt': 'gt', 'password': 'password', 'nmp': 'nmp', 'win': 'win', 'enter': 'enter', 'rt': 'rt', 'fol': 'fol', 'late': 'late', 'join': 'join', 'culture': 'culture', 'team': 'team', 'nonstop': 'nonstop', 'work': 'work', 'pushing': 'pushing', 'bounds': 'bounds', 'nft': 'nft', 'space': 'space', 'subscription': 'subscription', 'binaryx': 'binaryx', 'igo': 'igo', 'rh': 'rh', 'nox': 'nox', 'live': 'live', 'prepare': 'prepare', 'bnx': 'bnx', 'spot': 'spot', 'wallet': 'wallet', 'subscribe': 'subscribe', 'particip': 'particip', 'came': 'came', 'long': 'long', 'way': 'way', 'mint': 'mint', 'less': 'less', 'hours': 'hours', 'wait': 'wait', 'start': 'start', 'building': 'building', 'fam': 'fam', 'catch': 'catch', 'check': 'check', 'new': 'new', 'item': 'item', 'opensea': 'opensea', 'via': 'via', 'top': 'top', 'news': 'news', 'nftcommunity': 'nftcommunity', 'openseanft': 'openseanft', 'pick': 'pick', 'week': 'week', 'filthy': 'filthy', 'merica': 'merica', 'grade': 'grade', 'floor': 'floor', 'price': 'price', 'free': 'free', 'another': 'another', 'geeks': 'geeks', 'made': 'made', 'one': 'one', 'specially': 'specially', 'lucky': 'lucky', 'ninjas': 'ninjas', 'share': 'share', 'inj': 'inj', 'big': 'big', 'announcement': 'announcement', 'today': 'today', 'want': 'want', 'hook': 'hook', 'undead': 'undead', 'community': 'community', 'giving': 'giving', 'away': 'away', 'x': 'x', 'mi': 'mi', 'time': 'time', 'come': 'come', 'proud': 'proud', 'owner': 'owner', 'unique': 'unique', 'animated': 'animated', 'egg': 'egg', 'first': 'first', 'hari': 'hari', 'rolling': 'rolling', 'ends': 'ends', 'th': 'th', 'june': 'june', 'prize': 'prize', 'pool': 'pool', 'usd': 'usd', 'worth': 'worth', 'token': 'token', 'winner': 'winner', 'bitcoin': 'bitcoin', 'crypto': 'crypto', 'proof': 'proof', 'stake': 'stake', 'scam': 'scam', 'web': 'web', 'marketing': 'marketing', 'buzzword': 'buzzword', 'going': 'going', 'zero': 'zero', 'stablecoin': 'stablecoin', 'love': 'love', 'images': 'images', 'hey': 'hey', 'got': 'got', 'fresh': 'fresh', 'jacket': 'jacket', 'sr': 'sr', 'sloothzhangwithsloothz': 'sloothzhangwithsloothz', 'sol': 'sol', 'prizes': 'prizes', 'rules': 'rules', 'frens': 'frens', 'hr': 'hr', 'nftgiveaw': 'nftgiveaw', 'alert': 'alert', 'macd': 'macd', 'cross': 'cross', 'pair': 'pair', 'eos': 'eos', 'usdt': 'usdt', 'ipo': 'ipo', 'coinbase': 'coinbase', 'cryptocurrency': 'cryptocurrency', 'azukiart': 'azukiart', 'also': 'also', 'key': 'key', 'mysterious': 'mysterious', 'congratulations': 'congratulations', 'early': 'early', 'emlish': 'emlish', 'looks': 'looks', 'lion': 'lion', 'nftcollection': 'nftcollection', 'nftgiveaway': 'nftgiveaway', 'nftgiveaways': 'nftgiveaways', 'nftproject': 'nftproject', 'nfts': 'nfts', 'unknown': 'unknown', 'places': 'places', 'available': 'available', 'preview': 'preview', 'objkt': 'objkt', 'collection': 'collection', 'pieces': 'pieces', 'pointcloud': 'pointcloud', 'art': 'art', 'open': 'open', 'laf': 'laf', 'winners': 'winners', 'lets': 'lets', 'see': 'see', 'next': 'next', 'wizards': 'wizards', 'announcing': 'announcing', 'gold': 'gold', 'genesis': 'genesis', 'wizard': 'wizard', 'pass': 'pass', 'cost': 'cost', 'gas': 'gas', 'uti': 'uti', 'oak': 'oak', 'paradise': 'paradise', 'wls': 'wls', 'fr': 'fr', 'updates': 'updates', 'hiding': 'hiding', 'suspicious': 'suspicious', 'transfers': 'transfers', 'kujira': 'kujira', 'network': 'network', 'public': 'public', 'testnet': 'testnet', 'harpoon': 'harpoon', 'l': 'l', 'raising': 'raising', 'fund': 'fund', 'research': 'research', 'legalization': ...
# ------------------------
# Pandas Apply:   0%|          | 0/1000 [00:00<?, ?it/s]
# 0      [wl, spots, giveaway, like, follow, tag, friends]
# 1                           [true, words, world, friend]
# 2      [runx, airdrop, million, rnx, k, participants,...
# 3      [discord, officially, opening, gt, gt, passwor...
# 4      [discord, officially, opening, gt, gt, passwor...
#                              ...
# 995    [okayy, today, good, news, wl, amp, nfts, give...
# 996    [giving, away, wl, spots, dusktopia, qualify, ...
# 997    [nft, wizards, free, mint, giveaway, announcin...
# 998    [stay, hydrated, fun, wish, delightful, summer...
# 999             [gm, platform, best, crypto, nft, space]
# Name: Steaming, Length: 1000, dtype: object

# %%
prepocessing = dataset[['Tanggal&Waktu','Username','Clean_text','Tweet_tokenization','Stop_removal', 'Steaming']]

# %%
prepocessing
# Out:
#                  Tanggal&Waktu         Username  \
# 0    2022-06-14 08:34:52+00:00   iammasterblade
# 1    2022-06-14 08:34:51+00:00    naehrstff_nft
# 2    2022-06-14 08:34:51+00:00  mdzahid85418836
# 3    2022-06-14 08:34:51+00:00  annelie00284967
# 4    2022-06-14 08:34:51+00:00           tkirwi
# ..                         ...              ...
# 995  2022-06-14 08:32:51+00:00    mathslab_arts
# 996  2022-06-14 08:32:51+00:00         oden_nft
# 997  2022-06-14 08:32:51+00:00    amber99631422
# 998  2022-06-14 08:32:51+00:00         crtr_nft
# 999  2022-06-14 08:32:50+00:00    27ismailpekel
#
#                                             Clean_text  \
# 0          wl spots  giveaway        like and    fo...
# 1     some true words here  where in the world are ...
# 2       runx airdrop    million rnx for   k partici...
# 3      discord officially opening        gt    gt p...
# 4      discord officially opening        gt    gt p...
# ..                                                 ...
# 995    okayy so today s good news       wl  amp    ...
# 996    giving away   wl spots for dusktopia      to...
# 997    nft wizards free mint giveaway      announci...
# 998    stay hydrated and have fun  we wish you all ...
# 999    gm    which platform is the best for crypto ...
#
#                                     Tweet_tokenization  \
# 0    [, wl, spots, giveaway, like, and, follow, and...
# 1    [, some, true, words, here, where, in, the, wo...
# 2    [, runx, airdrop, million, rnx, for, k, partic...
# 3    [, discord, officially, opening, gt, gt, passw...
# 4    [, discord, officially, opening, gt, gt, passw...
# ..                                                 ...
# 995  [, okayy, so, today, s, good, news, wl, amp, n...
# 996  [, giving, away, wl, spots, for, dusktopia, to...
# 997  [, nft, wizards, free, mint, giveaway, announc...
# 998  [, stay, hydrated, and, have, fun, we, wish, y...
# 999  [, gm, which, platform, is, the, best, for, cr...
#
#                                           Stop_removal  \
# 0    [wl, spots, giveaway, like, follow, tag, friends]
# 1                         [true, words, world, friend]
# 2    [runx, airdrop, million, rnx, k, participants,...
# 3    [discord, officially, opening, gt, gt, passwor...
# 4    [discord, officially, opening, gt, gt, passwor...
# ..                                                 ...
# 995  [okayy, today, good, news, wl, amp, nfts, give...
# 996  [giving, away, wl, spots, dusktopia, qualify, ...
# 997  [nft, wizards, free, mint, giveaway, announcin...
# 998  [stay, hydrated, fun, wish, delightful, summer...
# 999           [gm, platform, best, crypto, nft, space]
#
#                                               Steaming
# 0    [wl, spots, giveaway, like, follow, tag, friends]
# 1                         [true, words, world, friend]
# 2    [runx, airdrop, million, rnx, k, participants,...
# 3    [discord, officially, opening, gt, gt, passwor...
# 4    [discord, officially, opening, gt, gt, passwor...
# ..                                                 ...
# 995  [okayy, today, good, news, wl, amp, nfts, give...
# 996  [giving, away, wl, spots, dusktopia, qualify, ...
# 997  [nft, wizards, free, mint, giveaway, announcin...
# 998  [stay, hydrated, fun, wish, delightful, summer...
# 999           [gm, platform, best, crypto, nft, space]
#
# [1000 rows x 6 columns]

# %%
prepocessing.to_csv("data/PreprocessingData.csv")
